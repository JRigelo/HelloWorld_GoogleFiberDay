# %% [markdown]
# # Data Science - Part 1
# ---

# %% [markdown]
# ### What is data science?

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas
import numpy
import seaborn
import matplotlib.pyplot as plt
import matplotlib.lines as lines
# %matplotlib inline

# %%
data = pandas.read_csv('Data/train.csv')
data = data[['Survived','Pclass', 'Name', 'Sex', 'Age', 'Fare', 'Embarked']]
data = data.rename(columns = {'Sex':'Gender'})

# %%
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#    Gender   Age     Fare Embarked
# 0    male  22.0   7.2500        S
# 1  female  38.0  71.2833        C
# 2  female  26.0   7.9250        S
# 3  female  35.0  53.1000        S
# 4    male  35.0   8.0500        S

# %%
data['Sex'] = data['Sex'].map({'male': 1, 'female': 0})

# %%
seaborn.lmplot(x='Sex', y='Fare', fit_reg=False, hue='Survived', data=data)
seaborn.plt.show()

# %%
fig=plt.figure(figsize=(16, 16))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
# setup mercator map projection.
m = Basemap(llcrnrlon=-100.,llcrnrlat=20.,urcrnrlon=20.,urcrnrlat=60.,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',projection='merc',\
            lat_0=40.,lon_0=-20.,lat_ts=20.)

lats = [50.9097,53.8758499, 54.2894659, 55.2333142, 
54.9846137,54.7064869, 51.5296651, 51.5536226, 51.7653115, 52.1625237, 
52.5809163, 52.9393892] 

lons = [1.4044, -9.9621948, -8.9583439, -7.6770179, -8.3771698, 
-8.7406732, -8.9529546, -9.7907148, -10.1531573, -10.4099873, 
-9.8456417, -9.4344939] 
m.plot(lats, lons, 'D-', markersize=10, linewidth=2, color='k', markerfacecolor='b')

m.drawcoastlines()
m.fillcontinents()
# draw parallels
m.drawparallels(np.arange(10,90,20),labels=[1,1,0,1])
# draw meridians
m.drawmeridians(np.arange(-180,180,30),labels=[1,1,0,1])
ax.set_title('Great Circle from New York to London')
plt.show()
